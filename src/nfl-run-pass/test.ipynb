# %%
import sys
from pathlib import Path

# Add src/ to the Python path
repo_root = Path("..").resolve()
src_path = repo_root / "src"
sys.path.append(str(src_path))

# %%
import os

print("CWD:", os.getcwd())
print("Contents here:", os.listdir())
# Out:
# CWD: c:\Users\sffra\Downloads\BSE 2025-2026\nflplaycaller\src\nfl-run-pass
# Contents here: ['config.py', 'data_loading.py', 'evaluation.py', 'features.py', 'models.py', 'pipeline.py', 'preprocessing.py', 'test.ipynb', 'tuning.py', '__init__.py']

# %%
from nfl_run_pass.config import CONFIG

CONFIG.paths.raw_data, CONFIG.data.season
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from nfl_run_pass.config import CONFIG
#       3 CONFIG.paths.raw_data, CONFIG.data.season
#
# ModuleNotFoundError: No module named 'nfl_run_pass'
